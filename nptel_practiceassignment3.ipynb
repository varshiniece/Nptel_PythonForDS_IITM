# %%
import pandas as pd
df = pd.read_csv('C:/Users/shiva/Downloads/Diamond.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.boxplot(x= df['price'] , y= df['cut'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='cut'>

# %%
df1 = pd.read_csv('C:/Users/shiva/Downloads/churn.csv')

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges        15
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
##Main assignment week3 
import pandas as pd
df2 = pd.read_csv('C:/Users/shiva/Downloads/hotel_bookings.csv')

# %%
df2.columns
# Out:
# Index(['hotel', 'is_canceled', 'arrival_date_year', 'arrival_date_month',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'country',
#        'market_segment', 'is_repeated_guest', 'reserved_room_type',
#        'assigned_room_type', 'deposit_type', 'agent', 'company',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data_hotel = df2.copy()

# %%
data_hotel.dtypes
# Out:
# hotel                         object
# is_canceled                    int64
# arrival_date_year              int64
# arrival_date_month            object
# arrival_date_day_of_month      int64
# stays_in_weekend_nights        int64
# stays_in_week_nights           int64
# adults                         int64
# children                       int64
# country                       object
# market_segment                object
# is_repeated_guest              int64
# reserved_room_type            object
# assigned_room_type            object
# deposit_type                  object
# agent                        float64
# company                      float64
# customer_type                 object
# reservation_status            object
# reservation_status_date       object
# dtype: object

# %%
data_hotel['reservation_status'].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %%
##data_ho2 = data_hotel[data_hotel.reservation_status == 'No-Show']
data_ho2 = data_hotel.loc[data_hotel.reservation_status.isin(['No-Show'])] #to filter column:reservation ststus is no-show

# %%
data_ho2
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 122    Resort Hotel            1               2015               July
# 328    Resort Hotel            1               2015               July
# 343    Resort Hotel            1               2015               July
# 467    Resort Hotel            1               2015               July
# 472    Resort Hotel            1               2015               July
# ...             ...          ...                ...                ...
# 29537  Resort Hotel            1               2016            October
# 29694  Resort Hotel            1               2017            January
# 32349  Resort Hotel            1               2017           February
# 36837  Resort Hotel            1               2017                May
# 40034    City Hotel            1               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
##how many bookings were not canceled in the year 2017?
data_hotel['is_canceled'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
uncancelled_2017_bookings = data_hotel.loc[(data_hotel['is_canceled'] == 0) & (data_hotel['arrival_date_year'] == 2017)]

# %%
uncancelled_2017_bookings.shape[0]
# Out:
# 9064
